# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import seaborn as sns

# %%
stdt = pd.read_csv("2009_Test_data_1.csv")

# %%
stdt
# Out:
#           acname partyname  partyvotes  boothno           candidatename  \
# 0   Pedakurapadu       TDP         353        1     KOMMALAPATI SRIDHAR
# 1   Pedakurapadu       INC         427        1  Pathan Noorjahan Begum
# 2   Pedakurapadu       PRP         355        1        Basu Linga Reddy
# 3   Pedakurapadu       TDP         227        2     KOMMALAPATI SRIDHAR
# 4   Pedakurapadu       INC         242        2  Pathan Noorjahan Begum
# 5   Pedakurapadu       PRP          67        2        Basu Linga Reddy
# 6   Pedakurapadu       TDP         170        3     KOMMALAPATI SRIDHAR
# 7   Pedakurapadu       INC         249        3  Pathan Noorjahan Begum
# 8   Pedakurapadu       PRP          90        3        Basu Linga Reddy
# 9   Pedakurapadu       TDP         248        4     KOMMALAPATI SRIDHAR
# 10  Pedakurapadu       INC         123        4  Pathan Noorjahan Begum
# 11  Pedakurapadu       PRP          37        4        Basu Linga Reddy
# 12  Pedakurapadu       TDP         274        5     KOMMALAPATI SRIDHAR
# 13  Pedakurapadu       INC         105        5  Pathan Noorjahan Begum
# 14  Pedakurapadu       PRP          19        5        Basu Linga Reddy
# 15  Pedakurapadu       TDP         274        6     KOMMALAPATI SRIDHAR
# 16  Pedakurapadu       INC         184        6  Pathan Noorjahan Begum
# 17  Pedakurapadu       PRP          49        6        Basu Linga Reddy
# 18  Pedakurapadu       TDP         303        7     KOMMALAPATI SRIDHAR
#
#     yearofpolling       mandal         village  \
# 0            2009  BELLAMKONDA  NANDIRAJUPALEM
# 1            2009  BELLAMKONDA  NANDIRAJUPALEM
# 2            2009  BELLAMKONDA  NANDIRAJUPALEM
# 3            2009  BELLAMKONDA  NANDIRAJUPALEM
# 4            2009  BELLAMKONDA  NANDIRAJUPALEM
# 5            2009  BELLAMKONDA  NANDIRAJUPALEM
# 6            2009  BELLAMKONDA   NAGIREDYPALEM
# 7            2009  BELLAMKONDA   NAGIREDYPALEM
# 8            2009  BELLAMKONDA   NAGIREDYPALEM
# 9            2009  BELLAMKONDA   NAGIREDYPALEM
# 10           2009  BELLAMKONDA   NAGIREDYPALEM
# 11           2009  BELLAMKONDA   NAGIREDYPALEM
# 12           2009  BELLAMKONDA     BELLAMKONDA
# 13           2009  BELLAMKONDA     BELLAMKONDA
# 14           2009  BELLAMKONDA     BELLAMKONDA
# 15           2009  BELLAMKONDA     BELLAMKONDA
# 16           2009  BELLAMKONDA     BELLAMKONDA
# 17           2009  BELLAMKONDA     BELLAMKONDA
# 18           2009  BELLAMKONDA     BELLAMKONDA
#
#                        villageAsECList
# 0    Bellamkonda Sivaru Nandirajupalem
# 1    Bellamkonda Sivaru Nandirajupalem
# 2    Bellamkonda Sivaru Nandirajupalem
# 3      Nandirajupalem H/O. Bellamkonda
# 4      Nandirajupalem H/O. Bellamkonda
# 5      Nandirajupalem H/O. Bellamkonda
# 6   Bellamkonda Sivaru Nagireddy Palem
# 7   Bellamkonda Sivaru Nagireddy Palem
# 8   Bellamkonda Sivaru Nagireddy Palem
# 9                        Nagiredypalem
# 10                       Nagiredypalem
# 11                       Nagiredypalem
# 12                         Bellamkonda
# 13                         Bellamkonda
# 14                         Bellamkonda
# 15                         Bellamkonda
# 16                         Bellamkonda
# 17                         Bellamkonda
# 18                         Bellamkonda

# %%
stdt.shape
# Out:
# (19, 9)

# %%
stdt.head()
# Out:
#          acname partyname  partyvotes  boothno           candidatename  \
# 0  Pedakurapadu       TDP         353        1     KOMMALAPATI SRIDHAR
# 1  Pedakurapadu       INC         427        1  Pathan Noorjahan Begum
# 2  Pedakurapadu       PRP         355        1        Basu Linga Reddy
# 3  Pedakurapadu       TDP         227        2     KOMMALAPATI SRIDHAR
# 4  Pedakurapadu       INC         242        2  Pathan Noorjahan Begum
#
#    yearofpolling       mandal         village  \
# 0           2009  BELLAMKONDA  NANDIRAJUPALEM
# 1           2009  BELLAMKONDA  NANDIRAJUPALEM
# 2           2009  BELLAMKONDA  NANDIRAJUPALEM
# 3           2009  BELLAMKONDA  NANDIRAJUPALEM
# 4           2009  BELLAMKONDA  NANDIRAJUPALEM
#
#                      villageAsECList
# 0  Bellamkonda Sivaru Nandirajupalem
# 1  Bellamkonda Sivaru Nandirajupalem
# 2  Bellamkonda Sivaru Nandirajupalem
# 3    Nandirajupalem H/O. Bellamkonda
# 4    Nandirajupalem H/O. Bellamkonda

# %%
df = pd.DataFrame(stdt, columns=["acname", "partyname", "partyvotes"])

# %%
df.plot(x="acname", y=["partyname", "partyvotes"], kind="bar", figsize=(9, 8))
# Out:
# <AxesSubplot:xlabel='acname'>

# %%
df.plot(x="partyname", y=["partyvotes"], kind="bar", figsize=(9, 8))
# Out:
# <AxesSubplot:xlabel='partyname'>

# %%
stdt.describe()
# Out:
#        partyvotes    boothno  yearofpolling
# count   19.000000  19.000000           19.0
# mean   199.789474   3.684211         2009.0
# std    119.198983   1.887168            0.0
# min     19.000000   1.000000         2009.0
# 25%     97.500000   2.000000         2009.0
# 50%    227.000000   4.000000         2009.0
# 75%    274.000000   5.000000         2009.0
# max    427.000000   7.000000         2009.0

# %%
stdt.describe().T
# Out:
#                count         mean         std     min     25%     50%     75%  \
# partyvotes      19.0   199.789474  119.198983    19.0    97.5   227.0   274.0
# boothno         19.0     3.684211    1.887168     1.0     2.0     4.0     5.0
# yearofpolling   19.0  2009.000000    0.000000  2009.0  2009.0  2009.0  2009.0
#
#                   max
# partyvotes      427.0
# boothno           7.0
# yearofpolling  2009.0

# %%
sns.pairplot(stdt)

# %%
stdt.isnull()
# Out:
#     acname  partyname  partyvotes  boothno  candidatename  yearofpolling  \
# 0    False      False       False    False          False          False
# 1    False      False       False    False          False          False
# 2    False      False       False    False          False          False
# 3    False      False       False    False          False          False
# 4    False      False       False    False          False          False
# 5    False      False       False    False          False          False
# 6    False      False       False    False          False          False
# 7    False      False       False    False          False          False
# 8    False      False       False    False          False          False
# 9    False      False       False    False          False          False
# 10   False      False       False    False          False          False
# 11   False      False       False    False          False          False
# 12   False      False       False    False          False          False
# 13   False      False       False    False          False          False
# 14   False      False       False    False          False          False
# 15   False      False       False    False          False          False
# 16   False      False       False    False          False          False
# 17   False      False       False    False          False          False
# 18   False      False       False    False          False          False
#
#     mandal  village  villageAsECList
# 0    False    False            False
# 1    False    False            False
# 2    False    False            False
# 3    False    False            False
# 4    False    False            False
# 5    False    False            False
# 6    False    False            False
# 7    False    False            False
# 8    False    False            False
# 9    False    False            False
# 10   False    False            False
# 11   False    False            False
# 12   False    False            False
# 13   False    False            False
# 14   False    False            False
# 15   False    False            False
# 16   False    False            False
# 17   False    False            False
# 18   False    False            False

# %%
stdt.isna()
# Out:
#     acname  partyname  partyvotes  boothno  candidatename  yearofpolling  \
# 0    False      False       False    False          False          False
# 1    False      False       False    False          False          False
# 2    False      False       False    False          False          False
# 3    False      False       False    False          False          False
# 4    False      False       False    False          False          False
# 5    False      False       False    False          False          False
# 6    False      False       False    False          False          False
# 7    False      False       False    False          False          False
# 8    False      False       False    False          False          False
# 9    False      False       False    False          False          False
# 10   False      False       False    False          False          False
# 11   False      False       False    False          False          False
# 12   False      False       False    False          False          False
# 13   False      False       False    False          False          False
# 14   False      False       False    False          False          False
# 15   False      False       False    False          False          False
# 16   False      False       False    False          False          False
# 17   False      False       False    False          False          False
# 18   False      False       False    False          False          False
#
#     mandal  village  villageAsECList
# 0    False    False            False
# 1    False    False            False
# 2    False    False            False
# 3    False    False            False
# 4    False    False            False
# 5    False    False            False
# 6    False    False            False
# 7    False    False            False
# 8    False    False            False
# 9    False    False            False
# 10   False    False            False
# 11   False    False            False
# 12   False    False            False
# 13   False    False            False
# 14   False    False            False
# 15   False    False            False
# 16   False    False            False
# 17   False    False            False
# 18   False    False            False

# %%
stdt.fillna(stdt.mean())
# Out:
# C:\Users\Sai Mahati\AppData\Local\Temp\ipykernel_14816\2018278846.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   stdt.fillna(stdt.mean())
#           acname partyname  partyvotes  boothno           candidatename  \
# 0   Pedakurapadu       TDP         353        1     KOMMALAPATI SRIDHAR
# 1   Pedakurapadu       INC         427        1  Pathan Noorjahan Begum
# 2   Pedakurapadu       PRP         355        1        Basu Linga Reddy
# 3   Pedakurapadu       TDP         227        2     KOMMALAPATI SRIDHAR
# 4   Pedakurapadu       INC         242        2  Pathan Noorjahan Begum
# 5   Pedakurapadu       PRP          67        2        Basu Linga Reddy
# 6   Pedakurapadu       TDP         170        3     KOMMALAPATI SRIDHAR
# 7   Pedakurapadu       INC         249        3  Pathan Noorjahan Begum
# 8   Pedakurapadu       PRP          90        3        Basu Linga Reddy
# 9   Pedakurapadu       TDP         248        4     KOMMALAPATI SRIDHAR
# 10  Pedakurapadu       INC         123        4  Pathan Noorjahan Begum
# 11  Pedakurapadu       PRP          37        4        Basu Linga Reddy
# 12  Pedakurapadu       TDP         274        5     KOMMALAPATI SRIDHAR
# 13  Pedakurapadu       INC         105        5  Pathan Noorjahan Begum
# 14  Pedakurapadu       PRP          19        5        Basu Linga Reddy
# 15  Pedakurapadu       TDP         274        6     KOMMALAPATI SRIDHAR
# 16  Pedakurapadu       INC         184        6  Pathan Noorjahan Begum
# 17  Pedakurapadu       PRP          49        6        Basu Linga Reddy
# 18  Pedakurapadu       TDP         303        7     KOMMALAPATI SRIDHAR
#
#     yearofpolling       mandal         village  \
# 0            2009  BELLAMKONDA  NANDIRAJUPALEM
# 1            2009  BELLAMKONDA  NANDIRAJUPALEM
# 2            2009  BELLAMKONDA  NANDIRAJUPALEM
# 3            2009  BELLAMKONDA  NANDIRAJUPALEM
# 4            2009  BELLAMKONDA  NANDIRAJUPALEM
# 5            2009  BELLAMKONDA  NANDIRAJUPALEM
# 6            2009  BELLAMKONDA   NAGIREDYPALEM
# 7            2009  BELLAMKONDA   NAGIREDYPALEM
# 8            2009  BELLAMKONDA   NAGIREDYPALEM
# 9            2009  BELLAMKONDA   NAGIREDYPALEM
# 10           2009  BELLAMKONDA   NAGIREDYPALEM
# 11           2009  BELLAMKONDA   NAGIREDYPALEM
# 12           2009  BELLAMKONDA     BELLAMKONDA
# 13           2009  BELLAMKONDA     BELLAMKONDA
# 14           2009  BELLAMKONDA     BELLAMKONDA
# 15           2009  BELLAMKONDA     BELLAMKONDA
# 16           2009  BELLAMKONDA     BELLAMKONDA
# 17           2009  BELLAMKONDA     BELLAMKONDA
# 18           2009  BELLAMKONDA     BELLAMKONDA
#
#                        villageAsECList
# 0    Bellamkonda Sivaru Nandirajupalem
# 1    Bellamkonda Sivaru Nandirajupalem
# 2    Bellamkonda Sivaru Nandirajupalem
# 3      Nandirajupalem H/O. Bellamkonda
# 4      Nandirajupalem H/O. Bellamkonda
# 5      Nandirajupalem H/O. Bellamkonda
# 6   Bellamkonda Sivaru Nagireddy Palem
# 7   Bellamkonda Sivaru Nagireddy Palem
# 8   Bellamkonda Sivaru Nagireddy Palem
# 9                        Nagiredypalem
# 10                       Nagiredypalem
# 11                       Nagiredypalem
# 12                         Bellamkonda
# 13                         Bellamkonda
# 14                         Bellamkonda
# 15                         Bellamkonda
# 16                         Bellamkonda
# 17                         Bellamkonda
# 18                         Bellamkonda

# %%
plt.bar(x="partyname", y=["acname", "partyvotes"], width = 0.72, kind = "bar" )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14816\2209654245.py in <module>
# ----> 1 plt.bar(x="partyname", y=["acname", "partyvotes"], width = 0.72, kind = "bar" )
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
plt.show()

# %%
plt.plot(x="Pedakurapadu", y=["partyvotes"], kind = "bar" )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14816\2214894184.py in <module>
# ----> 1 plt.plot(x="Pedakurapadu", y=["partyvotes"], kind = "bar" )
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     245         for pos_only in "xy":
#     246             if pos_only in kwargs:
# --> 247                 raise TypeError("{} got an unexpected keyword argument {!r}"
#     248                                 .format(self.command, pos_only))
#     249
#
# TypeError: plot got an unexpected keyword argument 'x'
